# %% [markdown]
# <a href="https://colab.research.google.com/github/Karthik1000/VizWiz/blob/master/VizWiz_202.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/DenisDsh/VizWiz-VQA-PyTorch.git
# Out:
# Cloning into 'VizWiz-VQA-PyTorch'...
# remote: Enumerating objects: 29, done.
# remote: Total 29 (delta 0), reused 0 (delta 0), pack-reused 29
# Unpacking objects: 100% (29/29), done.

# %%
# %cd VizWiz-VQA-PyTorch/
# Out:
# /content/VizWiz-VQA-PyTorch

# %%
# !wget https://ivc.ischool.utexas.edu/VizWiz_final/images/train.zip
# !unzip train.zip
# !rm train.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: train/VizWiz_train_00022049.jpg
#   inflating: train/VizWiz_train_00010269.jpg
#   inflating: train/VizWiz_train_00001449.jpg
#   inflating: train/VizWiz_train_00004288.jpg
#   inflating: train/VizWiz_train_00011536.jpg
#   inflating: train/VizWiz_train_00003138.jpg
#   inflating: train/VizWiz_train_00000748.jpg
#   inflating: train/VizWiz_train_00007422.jpg
#   inflating: train/VizWiz_train_00014674.jpg
#   inflating: train/VizWiz_train_00004900.jpg
#   inflating: train/VizWiz_train_00022766.jpg
#   inflating: train/VizWiz_train_00010259.jpg
#   inflating: train/VizWiz_train_00005425.jpg
#   inflating: train/VizWiz_train_00011918.jpg
#   inflating: train/VizWiz_train_00008013.jpg
#   inflating: train/VizWiz_train_00009540.jpg
#   inflating: train/VizWiz_train_00013833.jpg
#   inflating: train/VizWiz_train_00023196.jpg
#   inflating: train/VizWiz_train_00000160.jpg
#   inflating: train/VizWiz_train_00022912.jpg
# ...

# %%
# !mv train/ images/

# %%
# !ls images/
# Out:
# VizWiz_train_00000000.jpg  VizWiz_train_00007985.jpg  VizWiz_train_00015970.jpg
# VizWiz_train_00000001.jpg  VizWiz_train_00007986.jpg  VizWiz_train_00015971.jpg
# VizWiz_train_00000002.jpg  VizWiz_train_00007987.jpg  VizWiz_train_00015972.jpg
# VizWiz_train_00000003.jpg  VizWiz_train_00007988.jpg  VizWiz_train_00015973.jpg
# VizWiz_train_00000004.jpg  VizWiz_train_00007989.jpg  VizWiz_train_00015974.jpg
# VizWiz_train_00000005.jpg  VizWiz_train_00007990.jpg  VizWiz_train_00015975.jpg
# VizWiz_train_00000006.jpg  VizWiz_train_00007991.jpg  VizWiz_train_00015976.jpg
# VizWiz_train_00000007.jpg  VizWiz_train_00007992.jpg  VizWiz_train_00015977.jpg
# VizWiz_train_00000008.jpg  VizWiz_train_00007993.jpg  VizWiz_train_00015978.jpg
# VizWiz_train_00000009.jpg  VizWiz_train_00007994.jpg  VizWiz_train_00015979.jpg
# VizWiz_train_00000010.jpg  VizWiz_train_00007995.jpg  VizWiz_train_00015980.jpg
# VizWiz_train_00000011.jpg  VizWiz_train_00007996.jpg  VizWiz_train_00015981.jpg
# ...

# %%
# !wget https://ivc.ischool.utexas.edu/VizWiz_final/images/val.zip
# !unzip val.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: val/VizWiz_val_00000655.jpg
#   inflating: val/VizWiz_val_00007619.jpg
#   inflating: val/VizWiz_val_00000560.jpg
#   inflating: val/VizWiz_val_00006179.jpg
#   inflating: val/VizWiz_val_00001237.jpg
#   inflating: val/VizWiz_val_00002140.jpg
#   inflating: val/VizWiz_val_00004657.jpg
#   inflating: val/VizWiz_val_00003802.jpg
#   inflating: val/VizWiz_val_00002654.jpg
#   inflating: val/VizWiz_val_00007634.jpg
#   inflating: val/VizWiz_val_00005805.jpg
#   inflating: val/VizWiz_val_00003136.jpg
#   inflating: val/VizWiz_val_00001491.jpg
#   inflating: val/VizWiz_val_00002377.jpg
#   inflating: val/VizWiz_val_00001959.jpg
#   inflating: val/VizWiz_val_00004036.jpg
#   inflating: val/VizWiz_val_00004024.jpg
#   inflating: val/VizWiz_val_00005079.jpg
#   inflating: val/VizWiz_val_00004753.jpg
#   inflating: val/VizWiz_val_00003822.jpg
#   inflating: val/VizWiz_val_00000206.jpg
#   inflating: val/VizWiz_val_00000457.jpg
# ...

# %%
# !mv val/*.jpg images
# !rm -rf val.zip

# %%
# !ls val

# %%
# !ls images/
# Out:
# VizWiz_train_00000000.jpg  VizWiz_train_00010568.jpg  VizWiz_train_00021136.jpg
# VizWiz_train_00000001.jpg  VizWiz_train_00010569.jpg  VizWiz_train_00021137.jpg
# VizWiz_train_00000002.jpg  VizWiz_train_00010570.jpg  VizWiz_train_00021138.jpg
# VizWiz_train_00000003.jpg  VizWiz_train_00010571.jpg  VizWiz_train_00021139.jpg
# VizWiz_train_00000004.jpg  VizWiz_train_00010572.jpg  VizWiz_train_00021140.jpg
# VizWiz_train_00000005.jpg  VizWiz_train_00010573.jpg  VizWiz_train_00021141.jpg
# VizWiz_train_00000006.jpg  VizWiz_train_00010574.jpg  VizWiz_train_00021142.jpg
# VizWiz_train_00000007.jpg  VizWiz_train_00010575.jpg  VizWiz_train_00021143.jpg
# VizWiz_train_00000008.jpg  VizWiz_train_00010576.jpg  VizWiz_train_00021144.jpg
# VizWiz_train_00000009.jpg  VizWiz_train_00010577.jpg  VizWiz_train_00021145.jpg
# VizWiz_train_00000010.jpg  VizWiz_train_00010578.jpg  VizWiz_train_00021146.jpg
# VizWiz_train_00000011.jpg  VizWiz_train_00010579.jpg  VizWiz_train_00021147.jpg
# ...

# %%
# !cp preprocessing/image_features_extraction.py .
# !cp preprocessing/create_vocabs.py .
# !mkdir prepro_data

# %%
# !wget https://ivc.ischool.utexas.edu/VizWiz_final/vqa_data/Annotations.zip
# !unzip Annotations.zip
# !rm Annotations.zip
# Out:
# --2020-07-15 05:13:46--  https://ivc.ischool.utexas.edu/VizWiz_final/vqa_data/Annotations.zip
# Resolving ivc.ischool.utexas.edu (ivc.ischool.utexas.edu)... 146.6.168.124
# Connecting to ivc.ischool.utexas.edu (ivc.ischool.utexas.edu)|146.6.168.124|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1645983 (1.6M) [application/zip]
# Saving to: ‘Annotations.zip’
#
# Annotations.zip     100%[===================>]   1.57M  5.74MB/s    in 0.3s
#
# 2020-07-15 05:13:47 (5.74 MB/s) - ‘Annotations.zip’ saved [1645983/1645983]
#
# Archive:  Annotations.zip
#    creating: Annotations/
#   inflating: Annotations/val.json
#   inflating: Annotations/train.json
#   inflating: Annotations/test.json

# %%
# !python image_features_extraction.py
# Out:
# Found 31704 images in /content/VizWiz-VQA-PyTorch/images
# image_features_extraction.py:76: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   dummy_input = Variable(torch.ones(1, 3, config['img_size'], config['img_size']), volatile=True).cuda()
# Extracting features ...
#   0% 0/7926 [00:00<?, ?it/s]not required!!!!
#   0% 1/7926 [00:00<1:14:23,  1.78it/s]not required!!!!
#   0% 2/7926 [00:00<59:31,  2.22it/s]  not required!!!!
#   0% 3/7926 [00:00<49:39,  2.66it/s]not required!!!!
# not required!!!!
# not required!!!!
#   0% 6/7926 [00:01<40:44,  3.24it/s]not required!!!!
# not required!!!!
# not required!!!!
# not required!!!!
#   0% 10/7926 [00:01<33:19,  3.96it/s]not required!!!!
# not required!!!!
# not required!!!!
# not required!!!!
#   0% 14/7926 [00:02<29:50,  4.42it/s]not required!!!!
# not required!!!!
# not required!!!!
# not required!!!!
#   0% 18/7926 [00:02<25:15,  5.22it/s]not required!!!!
# not required!!!!
# ...

# %%
# !python create_vocabs.py
# Out:
# {'annotations': {'dir': '/content/VizWiz-VQA-PyTorch/Annotations',
#                  'max_length': 26,
#                  'min_count_word': 0,
#                  'path_vocabs': './prepro_data/vocabs.json',
#                  'top_ans': 3000},
#  'images': {'arch': 'ResNet152',
#             'dir': '/content/VizWiz-VQA-PyTorch/images',
#             'img_size': 448,
#             'mode': 'att',
#             'path_features': './prepro_data/resnet14x14.h5',
#             'preprocess_batch_size': 4,
#             'preprocess_data_workers': 4},
#  'logs': {'dir_logs': 'logs/vizwiz/'},
#  'model': {'attention': {'dropout': 0.5, 'glimpses': 2, 'mid_features': 512},
#            'classifier': {'dropout': 0.5},
#            'pooling': {'dim_h': 1024,
#                        'dim_q': 1024,
#                        'dim_v': 2048,
#                        'dropout_q': 0.5,
#                        'dropout_v': 0.5},
#            'pretrained_model': None,
# ...

# %%
# !python train.py
# Out:
# Streaming output truncated to the last 5000 lines.
# not present in the dataset!!! 5306
# not present in the dataset!!! 5307
# not present in the dataset!!! 5309
# not present in the dataset!!! 5401
# not present in the dataset!!! 5312
# not present in the dataset!!! 5127
# not present in the dataset!!! 5131
# not present in the dataset!!! 5407
# not present in the dataset!!! 5315
# not present in the dataset!!! 5565
# not present in the dataset!!! 5319
# not present in the dataset!!! 5135
# not present in the dataset!!! 5320
# not present in the dataset!!! 5323
# not present in the dataset!!! 5324
# not present in the dataset!!! 5413
# not present in the dataset!!! 5415
# not present in the dataset!!! 5416
# not present in the dataset!!! 5330
# not present in the dataset!!! 5420
# not present in the dataset!!! 5573
# not present in the dataset!!! 5574
# not present in the dataset!!! 5578
# not present in the dataset!!! 5338
# not present in the dataset!!! 5581
# ...
